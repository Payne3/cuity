# %%
# %matplotlib inline
# %matplotlib notebook
import pandas as pd
import numpy as np

# %%
crime_data = "Crimes_-_2018.csv"
housing_data = "Affordable_Rental.csv"

crime_df = pd.read_csv(crime_data)

housing_df = pd.read_csv(housing_data)

# %%
housing_df = housing_df.dropna()
housing_df
# Out:
#     Community Area Name  Community Area Number       Property Type  \
# 2             Englewood                     68         Multifamily
# 3       Washington Park                     40      Senior HUD 202
# 4         Humboldt Park                     23         Multifamily
# 5       Grand Boulevard                     38              Senior
# 6                Uptown                      3         Multifamily
# 7           South Shore                     43         Multifamily
# 9        Near West Side                     28         Multifamily
# 10          Albany Park                     14              Senior
# 11      Grand Boulevard                     38         Multifamily
# 14         Logan Square                     22         Multifamily
# 15        Humboldt Park                     23         Multifamily
# 16      Near North Side                      8          Supportive
# 17       North Lawndale                     29         Multifamily
# ...

# %%
housing_df = housing_df.drop(["X Coordinate", "Y Coordinate", "Location", "Historical Wards 2003-2015", "Census Tracts" ], axis=1)
housing_df
# Out:
#     Community Area Name  Community Area Number       Property Type  \
# 2             Englewood                     68         Multifamily
# 3       Washington Park                     40      Senior HUD 202
# 4         Humboldt Park                     23         Multifamily
# 5       Grand Boulevard                     38              Senior
# 6                Uptown                      3         Multifamily
# 7           South Shore                     43         Multifamily
# 9        Near West Side                     28         Multifamily
# 10          Albany Park                     14              Senior
# 11      Grand Boulevard                     38         Multifamily
# 14         Logan Square                     22         Multifamily
# 15        Humboldt Park                     23         Multifamily
# 16      Near North Side                      8          Supportive
# 17       North Lawndale                     29         Multifamily
# ...

# %%
housing_df["Zip Codes"] = housing_df["Zip Codes"].str.replace(',', '')
housing_df
# Out:
#     Community Area Name  Community Area Number       Property Type  \
# 2             Englewood                     68         Multifamily
# 3       Washington Park                     40      Senior HUD 202
# 4         Humboldt Park                     23         Multifamily
# 5       Grand Boulevard                     38              Senior
# 6                Uptown                      3         Multifamily
# 7           South Shore                     43         Multifamily
# 9        Near West Side                     28         Multifamily
# 10          Albany Park                     14              Senior
# 11      Grand Boulevard                     38         Multifamily
# 14         Logan Square                     22         Multifamily
# 15        Humboldt Park                     23         Multifamily
# 16      Near North Side                      8          Supportive
# 17       North Lawndale                     29         Multifamily
# ...

# %%
print(housing_df.dtypes)
# Out:
# Community Area Name       object
# Community Area Number      int64
# Property Type             object
# Property Name             object
# Address                   object
# Zip Code                   int64
# Phone Number              object
# Management Company        object
# Units                      int64
# Latitude                 float64
# Longitude                float64
# Wards                    float64
# Community Areas          float64
# Zip Codes                 object
# dtype: object

# %%
housing_df = housing_df.rename(columns={"Community Area Name": "Community_Area_Name", "Zip Codes": "Zip_Codes", "Community Area Number": "Community_Area_Number", "Property Type": "Property_Type", "Property Name": " Property_Name", "Phone Number": "Phone_Number", " Management Company": "Management_Company", "Zip Code": "Area_Code", "Community Areas": "Community_Areas", "Management Company": "Management_Company" })
housing_df
# Out:
#     Community_Area_Name  Community_Area_Number       Property_Type  \
# 2             Englewood                     68         Multifamily
# 3       Washington Park                     40      Senior HUD 202
# 4         Humboldt Park                     23         Multifamily
# 5       Grand Boulevard                     38              Senior
# 6                Uptown                      3         Multifamily
# 7           South Shore                     43         Multifamily
# 9        Near West Side                     28         Multifamily
# 10          Albany Park                     14              Senior
# 11      Grand Boulevard                     38         Multifamily
# 14         Logan Square                     22         Multifamily
# 15        Humboldt Park                     23         Multifamily
# 16      Near North Side                      8          Supportive
# 17       North Lawndale                     29         Multifamily
# ...

# %%
housing_df = housing_df.set_index("Community_Area_Name")
housing_df
# Out:
#                      Community_Area_Number       Property_Type  \
# Community_Area_Name
# Englewood                               68         Multifamily
# Washington Park                         40      Senior HUD 202
# Humboldt Park                           23         Multifamily
# Grand Boulevard                         38              Senior
# Uptown                                   3         Multifamily
# South Shore                             43         Multifamily
# Near West Side                          28         Multifamily
# Albany Park                             14              Senior
# Grand Boulevard                         38         Multifamily
# Logan Square                            22         Multifamily
# Humboldt Park                           23         Multifamily
# Near North Side                          8          Supportive
# North Lawndale                          29         Multifamily
# Pullman                                 50         Multifamily
# ...

# %%
export_csv = housing_df.to_csv("../Accuity Project/Housing_Final.csv")

# %%
connection_string = "root:Muskies95!!@localhost:3306/accuity?charset=utf8"
engine = create_engine(f'mysql://{connection_string}')

# %%
engine.table_names()

# %%
crime_df.to_sql(name="crimes", con=engine, if_exists="append", index=True)
